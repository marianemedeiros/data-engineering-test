# %%
import numpy
import pandas as pd
import psycopg2
import ipywidgets as widgets
import seaborn as sns

from datetime import date
from ipywidgets import fixed
from sqlalchemy import create_engine
from ipywidgets import interact, interact_manual

# %% [markdown]
# # Importa a planilha e cria o dataframe com as colunas requisitadas.
#
# Neste notbook criei um conjunto com menos casos para poder analisar e fazer o passo a passo para entender os dados e acompanhar se a abordagem que estou optando está fazendo sentido.
# * csv criado: products_teste

# %%
df = pd.read_csv ('../files/products_1.csv')
df_2 = pd.read_csv ('../files/products_2.csv')

print(df[:4])
print(df_2[:4])
# Out:
#        COMBUSTÍVEL   ANO        REGIÃO    ESTADO         Jan        Fev  \
# 0  GASOLINA C (m3)  2000  REGIÃO NORTE  RONDÔNIA  136073,253   9563,263
# 1  GASOLINA C (m3)  2000  REGIÃO NORTE      ACRE    3358,346  40001,853
# 2  GASOLINA C (m3)  2000  REGIÃO NORTE  AMAZONAS   20766,918  21180,919
# 3  GASOLINA C (m3)  2000  REGIÃO NORTE   RORAIMA    3716,032     3200,4
#
#           Mar        Abr        Mai        Jun        Jul        Ago  \
# 0   11341,229   9369,746  10719,983  11165,968  12312,451   11220,97
# 1    3065,758    3495,29    2946,93    3023,92    3206,93    3612,58
# 2  242742,352  17615,604    20258,2  18741,344  19604,023  20221,674
# 3    3339,332  43338,929     3259,3   3636,216   3631,569   3348,416
#
#          Set        Out        Nov        Dez      TOTAL
# 0  12482,281  13591,122   11940,57  11547,576  10818,094
# 1    3264,46    3835,74   3676,571    3225,61   3289,718
# 2  20792,616  19912,898  21869,338  21145,643  20633,175
# 3   3394,016   4078,616   3346,616     4029,9   4358,516
#              COMBUSTÍVEL   ANO        REGIÃO    ESTADO       Jan       Fev  \
# 0  ÓLEO DIESEL S-10 (m3)  2013  REGIÃO NORTE  RONDÔNIA  81453,67    3517,6
# 1  ÓLEO DIESEL S-10 (m3)  2013  REGIÃO NORTE      ACRE      1483     11202
# 2  ÓLEO DIESEL S-10 (m3)  2013  REGIÃO NORTE  AMAZONAS    6836,3  6784,232
# 3  ÓLEO DIESEL S-10 (m3)  2013  REGIÃO NORTE   RORAIMA    1475,3    1502,7
#
#          Mar       Abr     Mai     Jun      Jul     Ago      Set       Out  \
# 0     3681,7   4700,67  5339,2  6166,4  6539,65  7283,7  8082,85   7902,55
# 1        363       410     536     607      740     756      971      1174
# 2  61443,832  3190,585    3305    3391     3637    4250     4576  5756,879
# 3     1531,8   13423,7   795,4   757,2    939,8  1040,6      966     992,9
#
#         Nov     Dez   TOTAL
# 0   9383,15  9767,4  9088,8
# 1      1240    1439    1483
# 2  6228,636    6334  7154,2
# 3      1027  1083,8  1311,2

# %% [markdown]
# # Transformação
#
# Transformando os dados da planilha para o formato de
# * year_month
# * uf
# * product
# * unit
# * volume
# * created_at

# %%
def transform_df(data_frame):
    df_transform = pd.melt(data_frame, 
                id_vars=['COMBUSTÍVEL','ANO','ESTADO'], 
                value_vars=list(data_frame.columns[data_frame.columns.get_loc('Jan'):data_frame.columns.get_loc('Dez')]),
                var_name='month', 
                value_name='volume')

    df_transform['year_month'] = df_transform['ANO'].astype('str') + '_' + df_transform['month']  

    df_transform['volume'] = df_transform['volume'].str.replace(',','.').astype('float')

    df_transform.rename({'ESTADO':'uf','COMBUSTÍVEL':'product','ANO': 'year'}, axis='columns', inplace=True)
    return df_transform

df_oil = transform_df(df)
df_diesel = transform_df(df_2)

print(df_oil[:4])
print(df_diesel[:4])
# Out:
#            product  year        uf month      volume year_month
# 0  GASOLINA C (m3)  2000  RONDÔNIA   Jan  136073.253   2000_Jan
# 1  GASOLINA C (m3)  2000      ACRE   Jan    3358.346   2000_Jan
# 2  GASOLINA C (m3)  2000  AMAZONAS   Jan   20766.918   2000_Jan
# 3  GASOLINA C (m3)  2000   RORAIMA   Jan    3716.032   2000_Jan
#                  product  year        uf month    volume year_month
# 0  ÓLEO DIESEL S-10 (m3)  2013  RONDÔNIA   Jan  81453.67   2013_Jan
# 1  ÓLEO DIESEL S-10 (m3)  2013      ACRE   Jan   1483.00   2013_Jan
# 2  ÓLEO DIESEL S-10 (m3)  2013  AMAZONAS   Jan   6836.30   2013_Jan
# 3  ÓLEO DIESEL S-10 (m3)  2013   RORAIMA   Jan   1475.30   2013_Jan

# %% [markdown]
# # Conexão com o banco
#
# Estou utilizando o banco de dados PostgresSQL para amarzenar os dados. O banco foi configurado em um conteiner docker.
# * A imagem mostra o conteiner criado e ativo
# ![image.png](attachment:image.png)
#
# * neste ponto abro uma conexão com o banco para salvar os dados estruturados na tabela

# %%
connect = "postgresql://postgres:12345@localhost:5432/postgres"
engine = create_engine(connect)

def insert_db(df):
    df.to_sql(
        'test_raizen', 
        con=engine, 
        index=False,
        if_exists='append'
    )

# %%
insert_db(df_oil)
insert_db(df_diesel)

# %% [markdown]
# * figura com os dados salvos na tabela
# ![image.png](attachment:image.png)

# %%
df_database = pd.read_sql_table(
    'test_raizen',
    con=engine
)

df_database
# Out:
#                           product  year                   uf month  \
# 0                 GASOLINA C (m3)  2000             RONDÔNIA   Jan
# 1                 GASOLINA C (m3)  2000                 ACRE   Jan
# 2                 GASOLINA C (m3)  2000             AMAZONAS   Jan
# 3                 GASOLINA C (m3)  2000              RORAIMA   Jan
# 4                 GASOLINA C (m3)  2000                 PARÁ   Jan
# 5                 GASOLINA C (m3)  2000                AMAPÁ   Jan
# 6                 GASOLINA C (m3)  2000            TOCANTINS   Jan
# 7                 GASOLINA C (m3)  2000             MARANHÃO   Jan
# 8                 GASOLINA C (m3)  2000                PIAUÍ   Jan
# 9                 GASOLINA C (m3)  2000                CEARÁ   Jan
# 10                GASOLINA C (m3)  2000  RIO GRANDE DO NORTE   Jan
# 11                GASOLINA C (m3)  2000              PARAÍBA   Jan
# 12                GASOLINA C (m3)  2000           PERNAMBUCO   Jan
# 13                GASOLINA C (m3)  2000              ALAGOAS   Jan
# 14                GASOLINA C (m3)  2000              SERGIPE   Jan
# 15                GASOLINA C (m3)  2000                BAHIA   Jan
# 16                GASOLINA C (m3)  2000         MINAS GERAIS   Jan
# 17                GASOLINA C (m3)  2000       ESPÍRITO SANTO   Jan
# 18                GASOLINA C (m3)  2000       RIO DE JANEIRO   Jan
# 19                GASOLINA C (m3)  2000            SÃO PAULO   Jan
# 20                GASOLINA C (m3)  2000               PARANÁ   Jan
# 21                GASOLINA C (m3)  2000       SANTA CATARINA   Jan
# 22                GASOLINA C (m3)  2000    RIO GRANDE DO SUL   Jan
# 23                GASOLINA C (m3)  2000   MATO GROSSO DO SUL   Jan
# 24                GASOLINA C (m3)  2000          MATO GROSSO   Jan
# 25                GASOLINA C (m3)  2000                GOIÁS   Jan
# 26                GASOLINA C (m3)  2000     DISTRITO FEDERAL   Jan
# 27                GASOLINA C (m3)  2001             RONDÔNIA   Jan
# 28                GASOLINA C (m3)  2001                 ACRE   Jan
# 29                GASOLINA C (m3)  2001             AMAZONAS   Jan
# ...                           ...   ...                  ...   ...
# 61746   ÓLEO DIESEL MARÍTIMO (m3)  2020          MATO GROSSO   Nov
# 61747   ÓLEO DIESEL MARÍTIMO (m3)  2020                GOIÁS   Nov
# 61748   ÓLEO DIESEL MARÍTIMO (m3)  2020     DISTRITO FEDERAL   Nov
# 61749  ÓLEO DIESEL (OUTROS ) (m3)  2020             RONDÔNIA   Nov
# 61750  ÓLEO DIESEL (OUTROS ) (m3)  2020                 ACRE   Nov
# 61751  ÓLEO DIESEL (OUTROS ) (m3)  2020             AMAZONAS   Nov
# 61752  ÓLEO DIESEL (OUTROS ) (m3)  2020              RORAIMA   Nov
# 61753  ÓLEO DIESEL (OUTROS ) (m3)  2020                 PARÁ   Nov
# 61754  ÓLEO DIESEL (OUTROS ) (m3)  2020                AMAPÁ   Nov
# 61755  ÓLEO DIESEL (OUTROS ) (m3)  2020            TOCANTINS   Nov
# 61756  ÓLEO DIESEL (OUTROS ) (m3)  2020             MARANHÃO   Nov
# 61757  ÓLEO DIESEL (OUTROS ) (m3)  2020                PIAUÍ   Nov
# 61758  ÓLEO DIESEL (OUTROS ) (m3)  2020                CEARÁ   Nov
# 61759  ÓLEO DIESEL (OUTROS ) (m3)  2020  RIO GRANDE DO NORTE   Nov
# 61760  ÓLEO DIESEL (OUTROS ) (m3)  2020              PARAÍBA   Nov
# 61761  ÓLEO DIESEL (OUTROS ) (m3)  2020           PERNAMBUCO   Nov
# 61762  ÓLEO DIESEL (OUTROS ) (m3)  2020              ALAGOAS   Nov
# 61763  ÓLEO DIESEL (OUTROS ) (m3)  2020              SERGIPE   Nov
# 61764  ÓLEO DIESEL (OUTROS ) (m3)  2020                BAHIA   Nov
# 61765  ÓLEO DIESEL (OUTROS ) (m3)  2020         MINAS GERAIS   Nov
# 61766  ÓLEO DIESEL (OUTROS ) (m3)  2020       ESPÍRITO SANTO   Nov
# 61767  ÓLEO DIESEL (OUTROS ) (m3)  2020       RIO DE JANEIRO   Nov
# 61768  ÓLEO DIESEL (OUTROS ) (m3)  2020            SÃO PAULO   Nov
# 61769  ÓLEO DIESEL (OUTROS ) (m3)  2020               PARANÁ   Nov
# 61770  ÓLEO DIESEL (OUTROS ) (m3)  2020       SANTA CATARINA   Nov
# 61771  ÓLEO DIESEL (OUTROS ) (m3)  2020    RIO GRANDE DO SUL   Nov
# 61772  ÓLEO DIESEL (OUTROS ) (m3)  2020   MATO GROSSO DO SUL   Nov
# 61773  ÓLEO DIESEL (OUTROS ) (m3)  2020          MATO GROSSO   Nov
# 61774  ÓLEO DIESEL (OUTROS ) (m3)  2020                GOIÁS   Nov
# 61775  ÓLEO DIESEL (OUTROS ) (m3)  2020     DISTRITO FEDERAL   Nov
#
#            volume year_month
# 0      136073.253   2000_Jan
# 1        3358.346   2000_Jan
# 2       20766.918   2000_Jan
# 3        3716.032   2000_Jan
# 4       29755.907   2000_Jan
# 5        4096.700   2000_Jan
# 6        8046.450   2000_Jan
# 7       19185.495   2000_Jan
# 8        9638.450   2000_Jan
# 9       36847.944   2000_Jan
# 10      17949.950   2000_Jan
# 11      20266.851   2000_Jan
# 12      51905.707   2000_Jan
# 13     164548.309   2000_Jan
# 14      12707.571   2000_Jan
# 15      73630.193   2000_Jan
# 16     197289.300   2000_Jan
# 17      34425.525   2000_Jan
# 18     162775.786   2000_Jan
# 19     575302.161   2000_Jan
# 20     141272.276   2000_Jan
# 21      84778.684   2000_Jan
# 22     160079.439   2000_Jan
# 23      21692.937   2000_Jan
# 24      23245.280   2000_Jan
# 25      58254.692   2000_Jan
# 26     593389.679   2000_Jan
# 27      10500.844   2001_Jan
# 28       3345.625   2001_Jan
# 29      22763.560   2001_Jan
# ...           ...        ...
# 61746       0.000   2020_Nov
# 61747         NaN   2020_Nov
# 61748         NaN   2020_Nov
# 61749         NaN   2020_Nov
# 61750       0.000   2020_Nov
# 61751       0.000   2020_Nov
# 61752       0.000   2020_Nov
# 61753       0.000   2020_Nov
# 61754       0.000   2020_Nov
# 61755       0.000   2020_Nov
# 61756       0.000   2020_Nov
# 61757       0.000   2020_Nov
# 61758       0.000   2020_Nov
# 61759       0.000   2020_Nov
# 61760         NaN   2020_Nov
# 61761         NaN   2020_Nov
# 61762         NaN   2020_Nov
# 61763       0.000   2020_Nov
# 61764       0.000   2020_Nov
# 61765      25.000   2020_Nov
# 61766      25.000   2020_Nov
# 61767     411.000   2020_Nov
# 61768     318.000   2020_Nov
# 61769       0.000   2020_Nov
# 61770      50.000   2020_Nov
# 61771      10.000   2020_Nov
# 61772       0.000   2020_Nov
# 61773         NaN   2020_Nov
# 61774         NaN   2020_Nov
# 61775         NaN   2020_Nov
#
# [61776 rows x 6 columns]

# %% [markdown]
# # Conferindo os dados que vieram do banco.
#     * listando os produtos que estão na base

# %%
df_uf = df_database.groupby('uf')
df_product = df_database.groupby('product')

df_product.describe() 
#df_uf.describe()
# Out:
#                               year                                             \
#                              count    mean       std     min      25%     50%
# product
# ETANOL HIDRATADO (m3)       6237.0  2010.0  6.055786  2000.0  2005.00  2010.0
# GASOLINA C (m3)             6237.0  2010.0  6.055786  2000.0  2005.00  2010.0
# GASOLINA DE AVIAÇÃO (m3)    6237.0  2010.0  6.055786  2000.0  2005.00  2010.0
# GLP (m3)                    6237.0  2010.0  6.055786  2000.0  2005.00  2010.0
# QUEROSENE DE AVIAÇÃO (m3)   6237.0  2010.0  6.055786  2000.0  2005.00  2010.0
# QUEROSENE ILUMINANTE (m3)   6237.0  2010.0  6.055786  2000.0  2005.00  2010.0
# ÓLEO COMBUSTÍVEL (m3)       6237.0  2010.0  6.055786  2000.0  2005.00  2010.0
# ÓLEO DIESEL (OUTROS ) (m3)  2376.0  2016.5  2.291770  2013.0  2014.75  2016.5
# ÓLEO DIESEL (m3)            6237.0  2010.0  6.055786  2000.0  2005.00  2010.0
# ÓLEO DIESEL MARÍTIMO (m3)   2376.0  2016.5  2.291770  2013.0  2014.75  2016.5
# ÓLEO DIESEL S-10 (m3)       2376.0  2016.5  2.291770  2013.0  2014.75  2016.5
# ÓLEO DIESEL S-1800 (m3)     2376.0  2016.5  2.291770  2013.0  2014.75  2016.5
# ÓLEO DIESEL S-500 (m3)      2376.0  2016.5  2.291770  2013.0  2014.75  2016.5
#
#                                              volume                 \
#                                 75%     max   count           mean
# product
# ETANOL HIDRATADO (m3)       2015.00  2020.0  6168.0   64260.553348
# GASOLINA C (m3)             2015.00  2020.0  6168.0  179489.766317
# GASOLINA DE AVIAÇÃO (m3)    2015.00  2020.0  6169.0     353.634504
# GLP (m3)                    2015.00  2020.0  6168.0   71468.853097
# QUEROSENE DE AVIAÇÃO (m3)   2015.00  2020.0  6168.0   33008.110352
# QUEROSENE ILUMINANTE (m3)   2015.00  2020.0  6168.0     284.155702
# ÓLEO COMBUSTÍVEL (m3)       2015.00  2020.0  6168.0   28754.017095
# ÓLEO DIESEL (OUTROS ) (m3)  2018.25  2020.0  2309.0     155.920812
# ÓLEO DIESEL (m3)            2015.00  2020.0  6170.0  272429.199831
# ÓLEO DIESEL MARÍTIMO (m3)   2018.25  2020.0  2308.0    4238.804971
# ÓLEO DIESEL S-10 (m3)       2018.25  2020.0  2307.0  109939.050962
# ÓLEO DIESEL S-1800 (m3)     2018.25  2020.0  2307.0   19152.259896
# ÓLEO DIESEL S-500 (m3)      2018.25  2020.0  2307.0  188328.129214
#
#                                                                       \
#                                       std          min           25%
# product
# ETANOL HIDRATADO (m3)       389034.860320     0.000000   2165.143000
# GASOLINA C (m3)             557918.142056  1068.000000  25199.317758
# GASOLINA DE AVIAÇÃO (m3)      1124.821182   -56.769289     36.007000
# GLP (m3)                    214855.502191   780.361818  11577.040000
# QUEROSENE DE AVIAÇÃO (m3)   155415.502839     0.000000   1984.910500
# QUEROSENE ILUMINANTE (m3)     1780.527882    -0.120000      0.000000
# ÓLEO COMBUSTÍVEL (m3)       110800.697845     0.000000     89.218520
# ÓLEO DIESEL (OUTROS ) (m3)     899.130327     0.000000      0.000000
# ÓLEO DIESEL (m3)            787586.581664   493.000000  34552.245750
# ÓLEO DIESEL MARÍTIMO (m3)    18523.554073    -5.000000      0.000000
# ÓLEO DIESEL S-10 (m3)       323084.254660   223.000000  13462.398500
# ÓLEO DIESEL S-1800 (m3)     141311.860775  -122.000000      0.000000
# ÓLEO DIESEL S-500 (m3)      547794.701074     0.000000  19049.202522
#
#
#                                      50%            75%           max
# product
# ETANOL HIDRATADO (m3)        6212.623500   24846.100005  1.167378e+07
# GASOLINA C (m3)             53870.034500  140983.286000  1.084979e+07
# GASOLINA DE AVIAÇÃO (m3)       90.092007     297.851063  2.846390e+04
# GLP (m3)                    19245.796271   64460.578062  3.717165e+06
# QUEROSENE DE AVIAÇÃO (m3)    6178.565500   17050.631250  3.226147e+06
# QUEROSENE ILUMINANTE (m3)       7.226000     117.000000  8.398675e+04
# ÓLEO COMBUSTÍVEL (m3)        2507.405286   25060.589480  3.596543e+06
# ÓLEO DIESEL (OUTROS ) (m3)      0.000000       5.271000  1.429029e+04
# ÓLEO DIESEL (m3)            87946.651000  218823.076733  1.283015e+07
# ÓLEO DIESEL MARÍTIMO (m3)     439.441000    2288.750000  3.731071e+05
# ÓLEO DIESEL S-10 (m3)       38383.584000   92593.771500  6.044977e+06
# ÓLEO DIESEL S-1800 (m3)         0.000000      56.500000  4.065396e+06
# ÓLEO DIESEL S-500 (m3)      54221.460000  157883.180098  8.192393e+06

# %% [markdown]
# # Criando filtro que irá manipular os dados de acordo o UF e/ou produto escolhido
#
# * nessa etapa crio os filtros para agrupar os dados por UF e/ou produto como esta na tabela pivot do arquivo vendas-combustiveis-m3.xls

# %%
def add_total(df):
    total = df.sum()
    total.name = 'Total'
    return  df.append(total.transpose())

def search(uf, product, year, df):

    if uf == ['TODOS'] and product == ['TODOS'] and year != [0]:
        df = df.loc[df['year'].isin(year)]
        
    elif uf == ['TODOS'] and product != ['TODOS'] and year == [0]:
        df = df.loc[df['product'].isin(product)]
  
    elif uf != ['TODOS'] and product == ['TODOS'] and year == [0]:
        df = df.loc[df['uf'].isin(uf)]
    
    elif uf != ['TODOS'] and product != ['TODOS'] and year == [0]:
        uf = df['uf'].isin(uf)
        product =df['product'].isin(product)
        df = df.loc[uf & product]
    
    elif uf != ['TODOS'] and product == ['TODOS'] and year != [0]:
        uf =df['uf'].isin(uf)
        year =df['year'].isin(year)
        df = df.loc[uf & year]
    
    elif uf == ['TODOS'] and product != ['TODOS'] and year != [0]:
        product =df['product'].isin(product)
        year =df['year'].isin(year)
        df = df.loc[product & year]

    elif uf != ['TODOS'] and product != ['TODOS'] and year != [0]:
        uf = df['uf'].isin(uf)
        product =df['product'].isin(product)
        year =df['year'].isin(year)
        df = df.loc[uf & product & year]
    
    df_agg = df.groupby(by=['year','month'], as_index=False).agg({'volume':'sum'})
    df_agg = df_agg.pivot(index='month',columns='year',values='volume')
    
    df_agg = add_total(df_agg)
    return df_agg

# %% [markdown]
# # Definindo dropdown para escolha de UF e/ou Produto
#
# * na planilha vendas-combustiveis-m3.xls, tem uma coluna chamada VALOR_TOTAL, não consegui interpretar a forma como a coluna foi calculada. Verifiquei algumas possibilidade: soma, média, media, min, max... mas não obtive sucesso. Portanto considerei no desenvolvimento desse teste o valor total sendo a soma da venda de combustível do ano todo.

# %%
def show_data_by(state,product,year,df):
    print('State: ', state)
    print('Product: ', product)
    print('Years: ', 'TODOS' if year == 0 else year)
    return search([state],[product],[year],df)

def df_interact(df):
    interact(show_data_by,
                 state=widgets.Dropdown(options=numpy.insert(df['uf'].unique(),0,'TODOS'),description='Estado'),
                 product=widgets.Dropdown(options=numpy.insert(df['product'].unique(),0,'TODOS'),description='Produto'),
                 year=widgets.Dropdown(options=numpy.insert(df['year'].unique(),0,000),description='Ano'),
                 df=fixed(df)
                )

# %% [markdown]
# # Vendas, pelas distribuidoras, dos derivados combustíveis de petróleo por UF e produto - 2000-2020 (m3)

# %%
oil = df_database['product'].isin(['ETANOL HIDRATADO (m3)','GASOLINA C (m3)', 'GASOLINA DE AVIAÇÃO (m3)', 'GLP (m3)', 'QUEROSENE DE AVIAÇÃO (m3)'
                     ,'QUEROSENE ILUMINANTE (m3)', 'ÓLEO COMBUSTÍVEL (m3)', 'ÓLEO DIESEL (m3)'])

df_interact(df_database.loc[oil])
# Out:
# interactive(children=(Dropdown(description='Estado', options=('TODOS', 'RONDÔNIA', 'ACRE', 'AMAZONAS', 'RORAIM…

# %% [markdown]
# # Vendas, pelas distribuidoras, de óleo diesel por tipo e UF - 2013-2020 (m3)

# %%
diesel = df_database['product'].isin(['ÓLEO DIESEL (OUTROS ) (m3)', 'ÓLEO DIESEL MARÍTIMO (m3)', 'ÓLEO DIESEL S-10 (m3)', 'ÓLEO DIESEL S-1800 (m3)', 'ÓLEO DIESEL S-500 (m3)'])

df_interact(df_database.loc[diesel])
# Out:
# interactive(children=(Dropdown(description='Estado', options=('TODOS', 'RONDÔNIA', 'ACRE', 'AMAZONAS', 'RORAIM…

# %% [markdown]
# # Alguns gráficos para compreender os dados

# %%
def plot(df_plot, plot_title, set_title, x_axis, y_axis, hue_axis):
    g = sns.catplot(
        data=df_plot, kind="bar",
        x=x_axis, y=y_axis, hue=hue_axis,
        ci="sd", palette="dark", alpha=.9, height=11
    )
    g.despine(left=True)
    g.set_axis_labels("", plot_title)
    g.legend.set_title(set_title)
    g.set_xticklabels(rotation=90)

# %% [markdown]
# # Gráfico 1
# O primeiro gráfico mostra a relação de vendas dos produtos (derivados combustíveis de petróleo) nos últimos 10 anos.
# * podemos observar que Gasolina C e Oleo Diesel foram os produtos mais vendidos ao longos dos últimos 10 anos.

# %%
df_oil = df_database.loc[oil]
plot(df_oil.loc[df_oil['year'] >= 2010].groupby(by=['product','year'], as_index=False).agg({'volume':'sum'}),
    "Venda de produtos por ano. Ano >= 2010", 'Produtos', 'year', 'volume', 'product')

# %% [markdown]
# # Gráfico 2
# O segundo gráfico mostra os produtos mais vendidos, Gasolina C e Óleo Diesel, por estado.
# * observamos que os estados de São Paulo e Minas Gerais foram os maiores consumidores desses produtos nos últimos 10 anos.

# %%
filtro_product =df_oil['product'].isin(['GASOLINA C (m3)','ÓLEO DIESEL (m3)'])
filtro = df_oil.loc[filtro_product]
plot(filtro.groupby(by=['uf','product'], as_index=False).agg({'volume':'sum'}),
    "Venda de OLEO DIESEL e GASOLINA por estado.", 'Produtos','uf', 'volume', 'product')

# %% [markdown]
# # Gráfico 3
#
# Venda de Óleo Diesel e seus tipos por ano, como a base tem registros apenas de 2013 até 2020, não foi filtrado por ano.
#
# * nota-se que os tipos Óleo Diesel S-500 e o Óleo Diesel S-10 foram os mais vendidos entre 2013 e 2020.
# * os óleos diesel Maritimo e S-1800 apresentam menor quantididade de m3 vendido nos últimos anos.

# %%
df_diesel = df_database.loc[diesel]
plot(df_diesel.groupby(by=['product','year'], as_index=False).agg({'volume':'sum'}),
    "Venda de Oleo Diesel (e seus tipos) por ano.", 'Produtos', 'year', 'volume', 'product')

# %% [markdown]
# # Gráfico 4
#
# Venda de Óleo Diesel S-500 e Óleo Diesel S-10 por estado.
#
# * os estados de São Paulo e Minas Gerais foram os maiores consumidores de óleo diesel, assim como foram os que mais consumiram derivados combustíveis de petróleo (Gasolina C e Óleo Diesel)

# %%
filtro = df_diesel.loc[df_diesel['product'].isin(['ÓLEO DIESEL S-10 (m3)', 'ÓLEO DIESEL S-500 (m3)'])]
plot(filtro.groupby(by=['uf','product'], as_index=False).agg({'volume':'sum'}),
    "Venda de ÓLEO DIESEL S-10 e ÓLEO DIESEL S-500 por estado.", 'Produtos','uf', 'volume', 'product')

# %% [markdown]
# # Gráfico 5
#
# * os dois tipos de óleo diesel menos vendidos nos últimos anos, são mais comercializados em Minas Gerais e Rio de Janeiro, onde o óleo diesel marítimo é mais vendido no Rio de Janeiro e o S-1800 em Minas Gerais.

# %%
filtroLessUsed = df_diesel.loc[df_diesel['product'].isin(['ÓLEO DIESEL MARÍTIMO (m3)', 'ÓLEO DIESEL S-1800 (m3)'])]
plot(filtroLessUsed.groupby(by=['uf','product'], as_index=False).agg({'volume':'sum'}),
    "Venda de ÓLEO DIESEL MARÍTIMO e ÓLEO DIESEL S-1800 por estado.", 'Produtos','uf', 'volume', 'product')
